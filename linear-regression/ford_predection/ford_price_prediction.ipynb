# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np

# %%
df =pd.read_csv('ford.csv')

# %%
df.sample(10)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 3271      Fiesta  2018  10731       Manual     4026   Petrol  145  65.7
# 3147       Focus  2017  10178       Manual    19325   Diesel    0  74.3
# 7719        Kuga  2019  19498       Manual     9503   Petrol  145  39.2
# 17316       Kuga  2011   7499       Manual    56000   Petrol  555  28.5
# 12673     Fiesta  2019  13999       Manual    14755   Petrol  145  58.9
# 14495     Mondeo  2017   7391       Manual   111000   Diesel   20  67.3
# 16061     Fiesta  2016   7499       Manual    27775   Petrol  125  54.3
# 983        Focus  2019  25500       Manual     6338   Petrol  145  34.5
# 7052       Focus  2018  15999       Manual     6000   Diesel  145  74.3
# 14233   EcoSport  2017   9399       Manual    15285   Petrol  145  44.8
#
#        engineSize
# 3271          1.0
# 3147          1.5
# 7719          1.5
# 17316         2.5
# 12673         1.0
# 14495         2.0
# 16061         1.2
# 983           2.3
# ...

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  object
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  object
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  object
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
sns.histplot(df['price'],bins=50,kde=True)
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include=np.number).corr(method='pearson'), annot=True)
plt.show()

# %%
sns.boxplot(x='year', y='price', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x='mileage', y='price', data=df)
plt.show()

# %%
sns.boxplot(x='engineSize', y='price', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='transmission', y='price', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='fuelType', y='price', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='model', y='price', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='tax', y='price', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='mpg', y='price', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x_one_encoded=pd.get_dummies(x,columns=['model','transmission','fuelType'],drop_first=True)

# %%
x_one_encoded=x_one_encoded.astype(int)

# %%
x_one_encoded
# Out:
#        year  mileage  tax  mpg  engineSize  model_ C-MAX  model_ EcoSport  \
# 0      2017    15944  150   57           1             0                0
# 1      2018     9083  150   57           1             0                0
# 2      2017    12456  150   57           1             0                0
# 3      2019    10460  145   40           1             0                0
# 4      2019     1482  145   48           1             0                0
# ...     ...      ...  ...  ...         ...           ...              ...
# 17961  2017    16700  150   47           1             0                0
# 17962  2014    40700   30   57           1             0                0
# 17963  2015     7010   20   67           1             0                0
# 17964  2018     5007  145   57           1             0                0
# 17965  2015     5007   22   57           1             0                0
#
#        model_ Edge  model_ Escort  model_ Fiesta  ...  model_ Tourneo Connect  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

columns = ['model', 'transmission', 'fuelType']

Xlable = x.copy()
label_encoders = {}

for col in columns:
    le = LabelEncoder()
    Xlable[col] = le.fit_transform(Xlable[col].astype(str))
    label_encoders[col] = le

# %%
Xlable.sample(10)
# Out:
#        model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 14365      2  2016             1    16838         4  160  44.8         1.5
# 15093      5  2019             1     8732         4  145  58.9         1.0
# 13155      2  2017             1    16237         4  125  52.3         1.0
# 9811       5  2017             1    23985         4  125  54.3         1.2
# 12654      1  2018             1    12073         4  150  48.7         1.0
# 12718      5  2019             1     7800         4  145  58.9         1.0
# 12892      6  2017             1    33310         0  145  74.3         1.5
# 8837       5  2015             1    31945         4    0  65.7         1.0
# 1796       6  2015             1    54701         0   20  67.3         1.6
# 7193       0  2017             1    26341         4  150  56.5         1.0

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
columns_to_scale = ['year', 'mileage', 'tax', 'mpg','engineSize']

x_one_encoded[columns_to_scale] = scaler.fit_transform(x_one_encoded[columns_to_scale])

# %%
Xlable.columns
# Out:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')

# %%
Xlable[['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
       'engineSize']]=scaler.fit_transform(Xlable[['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
       'engineSize']])

# %%
Xlable
# Out:
#           model      year  transmission   mileage  fuelType       tax  \
# 0     -0.460699  0.065128     -2.670032 -0.380998  0.688777  0.591358
# 1     -0.211477  0.552866      0.041351 -0.733359  0.688777  0.591358
# 2     -0.211477  0.065128      0.041351 -0.560132  0.688777  0.591358
# 3     -0.460699  1.040605      0.041351 -0.662640  0.688777  0.510727
# 4     -0.460699  1.040605     -2.670032 -1.123724  0.688777  0.510727
# ...         ...       ...           ...       ...       ...       ...
# 17961 -1.706810  0.065128      0.041351 -0.342172  0.688777  0.591358
# 17962 -1.706810 -1.398088      0.041351  0.890398  0.688777 -1.343791
# 17963 -0.211477 -0.910349      0.041351 -0.839822 -1.454098 -1.505053
# 17964  1.034634  0.552866      0.041351 -0.942690  0.688777  0.510727
# 17965  4.025302 -0.910349      0.041351 -0.942690  0.688777 -1.472801
#
#             mpg  engineSize
# 0     -0.020442   -0.811386
# 1     -0.020442   -0.811386
# 2     -0.020442   -0.811386
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
x_one_encoded_train,x_one_encoded_test,y_train,y_test=train_test_split(x_one_encoded,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_one_encoded_train, y_train)
# Out:
# LinearRegression()

# %%
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# Print the results
print(f"R² Score: {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# R² Score: 0.8464177711972799
# Mean Absolute Error (MAE): 1371.1900784920842
# Mean Squared Error (MSE): 3442092.8490463574

# %%
x_label_train,x_label_test,y_train,y_test=train_test_split(Xlable,y,test_size=0.2,random_state=42)

# %%
model2 = LinearRegression()

# %%
model2.fit(x_label_train, y_train)
# Out:
# LinearRegression()

# %%
y_label_pred=model2.predict(x_label_test)

# %%
r22 = r2_score(y_test, y_label_pred)
mae2 = mean_absolute_error(y_test, y_label_pred)
mse2 = mean_squared_error(y_test, y_label_pred)

print(f"R² Score: {r22}")
print(f"Mean Absolute Error (MAE): {mae2}")
print(f"Mean Squared Error (MSE): {mse2}")
# Out:
# R² Score: 0.7365884288851352
# Mean Absolute Error (MAE): 1776.8255281707004
# Mean Squared Error (MSE): 5903593.744919552
